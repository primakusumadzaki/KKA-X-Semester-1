# %% [markdown]
# <a href="https://colab.research.google.com/github/primakusumadzaki/KKA-X-Semester-1/blob/main/Mantap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
jari_jari = int(input("Masukkan jari-jari dari bola (cm): "))
pi = 22/7
volume_bola = 4/3 * pi * jari_jari**3
print (f" volume bola adalah {volume_bola} cm^3. ")
# Out:
# Masukkan jari-jari dari bola (cm): 7
#  volume bola adalah 1437.333333333333 cm^3.

# %%
print(6>=6)
# Out:
# True

# %%
print(8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print(8<10)
# Out:
# True

# %%
print(8>10)
# Out:
# False

# %%
not(5<=5)
# Out:
# False

# %%
8>7 and 6<5
# Out:
# False

# %%
7<=1 or 2!=2
# Out:
# False

# %%
not(0==1 and 1!=1)
# Out:
# True

# %%
not(5<10 or 5<=10)
# Out:
# False

# %%
jari_jari = int(input("Masukkan jari-jari dari tabung (cm) : "))
pi = 22/7
tinggi = int(input(" Masukkan tinggi dari tabung (cm): "))
volume_tabung = pi *jari_jari**2 * tinggi
print (f" volume tabung adalah {volume_tabung} cm^3 ")
# Out:
# Masukkan jari-jari dari tabung (cm) : 5
#  Masukkan tinggi dari tabung (cm): 4
#  volume tabung adalah 314.2857142857143 cm^3
