# %% [markdown]
# <a href="https://colab.research.google.com/github/primakusumadzaki/KKA-X-Semester-1/blob/main/1_Fungsi_print_prima_kusuma_dzaki_X_11_Ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama:prima kusuma dzaki
#
# Kelas:kelas x. 11
#
# No absen:27

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print("prima kusuma dzaki")
# Out:
# prima kusuma dzaki

# %% [markdown]
# #Menampilkan Nilai variabel

# %%
Nama_saudara = "hafidz"
print(Nama_saudara)
# Out:
# hafidz

# %%
Jumlah_saudara = 1
print(Jumlah_saudara)
# Out:
# 1

# %% [markdown]
# #Menampilkan Teks Bebas dan nilai variabel

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan Tanda Koma

# %%
print("saya memiliki saudara sebanyak", Jumlah_saudara, "Nama_saudara saya adalah", Nama_saudara)
# Out:
# saya memiliki saudara sebanyak 1 Nama_saudara saya adalah hafidz

# %% [markdown]
# #Menampilkan Teks Bebas dan nilai Variabel Menggunakan Tanda plus

# %%
print("saya memiliki saudara sebanyak " + str(Jumlah_saudara) +". "+" Nama_saudara saya adalah " + Nama_saudara)
# Out:
# saya memiliki saudara sebanyak 1.  Nama_saudara saya adalah hafidz

# %% [markdown]
# #Menampilkan Teks bebas dan nilai variabel menggunakan F string

# %%
print(f"saya memiliki saudara sebanyak {Jumlah_saudara}. Nama saudara saya adalah {Nama_saudara}.")
# Out:
# saya memiliki saudara sebanyak 1. Nama saudara saya adalah hafidz.

# %% [markdown]
# #Escape Character

# %%
print("Nama: Prima Kusuma Dzaki")
print("kelas: X.11")
print ("No.absen: 27")
# Out:
# Nama: Prima Kusuma Dzaki
# kelas: X.11
# No.absen: 27

# %%
print("Nama: Prima Kusuma Dzaki H\nkelas: X.11\nNo. Absen: 27")
# Out:
# Nama: Prima Kusuma Dzaki H
# kelas: X.11
# No. Absen: 27

# %%
print("""Nama\t\t: Prima Kusuma Dzaki
kelas\t\t: X.11
No. absen\t: 27""")
# Out:
# Nama		: Prima Kusuma Dzaki
# kelas		: X.11
# No. absen	: 27

# %%
print("prima kusuma dzaki")
# Out:
# prima kusuma dzaki

# %%
print('prima kusuma dzaki')
# Out:
# prima kusuma dzaki

# %%
print('habib ja\'far')
# Out:
# habib ja'far

# %%
print("habib ja'far")
# Out:
# habib ja'far

# %%
print('prima kusuma dzaki,".')
# Out:
# prima kusuma dzaki,".

# %%
print('Bu Shinta berkata, "Harap fokus menyimak! ".')
# Out:
# Bu Shinta berkata, "Harap fokus menyimak! ".

# %%
print("Bu Shinta berkata, \"Harap fokus menyimak!\".")
# Out:
# Bu Shinta berkata, "Harap fokus menyimak!".

# %%
print("Lokasi penyimpanan tugas KKA di D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\MAN Demak\KKA\Tugas

# %% [markdown]
# #Fungsi parameter

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 ="adzka"
nama_siswa_3 ="Haidar"

print(nama_siswa_1, nama_siswa_2, sep="-")
# Out:
# Daffanes-adzka

# %%
print(nama_siswa_3, end="#")
print(nama_siswa_2, end="#")
print(nama_siswa_1, end="#")
print(nama_siswa_2)
# Out:
# Haidar#adzka#Daffanes#adzka
